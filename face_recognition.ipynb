# %% [markdown]
# # face_recognition

# %%
import cv2
cam = cv2.VideoCapture(0)
detector=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

Id=input('enter your id :')
sampleNum=0
while True:
    ret, img = cam.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    if ret==False:
        continue
    
    faces = detector.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        
        #incrementing sample number 
        sampleNum=sampleNum+1
        #saving the captured face in the dataset folder
        cv2.imwrite("DataSet/dataSet."+Id +'.'+ str(sampleNum) + ".jpg", gray[y:y+h,x:x+w])

        cv2.imshow('frame',img)
    
    #wait for 100 miliseconds 
    if cv2.waitKey(100) & 0xFF == ord('q'):
        break
    # break if the sample number is morethan 20

    elif sampleNum>20:
        break

cam.release()
cv2.destroyAllWindows()
# Out:
# enter your id :1

# %%
import cv2,os
import numpy as np
from PIL import Image

recognizer = cv2.face.LBPHFaceRecognizer_create()
path = "DataSet"
detector=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def getImagesAndLabels(path):
    #get the path of all the files in the folder
    imagePaths=[os.path.join(path,f) for f in os.listdir(path)]
    print(imagePaths)
    #create empth face list
    faceSamples=[]
    #create empty ID list
    Ids=[]
    #now looping through all the image paths and loading the Ids and the images
    for imagePath in imagePaths:
        if imagePath == "dataSet/.DS_Store":
            continue
        #loading the image and converting it to gray scale
        pilImage=Image.open(imagePath).convert('L')
        #Now we are converting the PIL image into numpy array
        imageNp=np.array(pilImage,'uint8')
        #getting the Id from the image
        Id=int(os.path.split(imagePath)[-1].split(".")[1])
        # extract the face from the training image sample
        faces=detector.detectMultiScale(imageNp)
        #If a face is there then append that in the list as well as Id of it
        for (x,y,w,h) in faces:
            faceSamples.append(imageNp[y:y+h,x:x+w])
            Ids.append(Id)
    return faceSamples,Ids

faces,Ids = getImagesAndLabels('DataSet')
recognizer.train(faces, np.array(Ids))
recognizer.save('trainner/trainner.yml')
# Out:
# ['DataSet\\dataSet.1.1.jpg', 'DataSet\\dataSet.1.10.jpg', 'DataSet\\dataSet.1.11.jpg', 'DataSet\\dataSet.1.12.jpg', 'DataSet\\dataSet.1.13.jpg', 'DataSet\\dataSet.1.14.jpg', 'DataSet\\dataSet.1.15.jpg', 'DataSet\\dataSet.1.16.jpg', 'DataSet\\dataSet.1.17.jpg', 'DataSet\\dataSet.1.18.jpg', 'DataSet\\dataSet.1.19.jpg', 'DataSet\\dataSet.1.2.jpg', 'DataSet\\dataSet.1.20.jpg', 'DataSet\\dataSet.1.21.jpg', 'DataSet\\dataSet.1.3.jpg', 'DataSet\\dataSet.1.4.jpg', 'DataSet\\dataSet.1.5.jpg', 'DataSet\\dataSet.1.6.jpg', 'DataSet\\dataSet.1.7.jpg', 'DataSet\\dataSet.1.8.jpg', 'DataSet\\dataSet.1.9.jpg']

# %%
import cv2
import numpy as np
from PIL import Image
cascadePath='haarcascade_frontalface_default.xml'
faceCascade=cv2.CascadeClassifier(cascadePath)
recognizer = cv2.face_LBPHFaceRecognizer.create()
recognizer.read('trainner/trainner.yml') 
id=0
cam = cv2.VideoCapture(0)
while True:
    ret, im = cam.read()
    gray=cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
    faces=faceCascade.detectMultiScale(gray, 1.2,5)
    for(x,y,w,h) in faces:
        cv2.rectangle(im,(x,y),(x+w,y+h),(225,0,0),2)
        id, conf = recognizer.predict(gray[y:y+h,x:x+w])
        print(conf)
        if(conf<50):
            if(id==1):
                id="Arnav" + " Age : 21 "
            elif(id==2):
                id="Unknow"
        else:
            id="Arnav"
        cv2.putText(im, str(id),(x,y+h),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 4)
    cv2.imshow('im',im) 
    if (cv2.waitKey(1)==ord('q')):
        break
cam.release()
cv2.destroyAllWindows()
# Out:
# 69.1390758912808
# 65.39419009456901
# 66.97252175009972
# 71.7903015519405
# 69.27986137180432
# 69.6784851116181
# 69.55627732886117
# 69.10673813619495
# 70.00792724602171
# 66.6126940283084
# 74.86731775164039
# 76.6478268351275
# 64.01385162171914
# 68.25206520320528
# 68.04758694158558
# 69.13713361746204
# 67.41582970196868
# 66.49932541388009
# 65.00125583663727
# 66.98283129085908
# 64.66396997911865
# 70.79952923326246
# 72.73649157839142
# 67.39365713403309
# 67.62090473578716
# 67.94858216141533
# 69.4258333528619
# 72.21546494718109
# 78.043663301287
# 76.37204459184932
# 68.5121714043603
# 69.83043908248737
# 70.03201795672894
# 76.0008714544719
# 68.72990337893687
# 71.30061653841264
# 71.45426528634074
# 69.50195135341991
# 69.79990176632944
# 70.40760901473585
# 74.36512916735074
# 69.42084183039259
# 75.4414757363186
# 69.62647446160896
# 70.59779026530686
# 68.08796751675484
# 69.64336003855412
# 69.57227891128892
# 69.23608996801211
# 69.27478455199618
# 65.1118480590522
# 71.71833936871111
# 68.64474830769252
# 69.55827052644601
# 68.7434819283197
# 68.8761522316233
# 70.91265318587864
# 69.35634393876808
# 72.9169618260683
# 71.13700291510368
# 80.71855402634525
# 80.79141128906068
# 84.34071568120399
# 61.91965630388949
# 62.33194927312836
# 74.85496596080385
# 74.17565963408686
# 156.7071549525125
# 70.68477696362588
# 153.33907208435946
# 82.1570914589272
# 154.9767971562364
# 82.4314993996578
# 153.97159616610028
# 74.74041448894722
# 153.43191012067496
# 72.63383658015906
# 84.94371993395623
# 151.8463717153542
# 69.30414205665974
# 69.84954260595876
# 71.87157187027158
# 77.87432751177526
# 79.58568142849482
# 71.22741342085614
# 85.31126014243556
# 75.95971813753964
# 78.63926527988691
# 90.01674958754406
# 149.9839859682728
# 91.84756667709162
# 152.4994406815851
# 93.69748255252996
# 151.3742020874692
# 93.08651431071681
# 149.29896368520227
# 70.09683902899373
# 152.6445165113844
# 68.38203141971037
# 78.61684586426897
# 81.76818316860731
# 79.7068272515526
# 155.22296501874527
# 69.73013641922981
# 153.16057110321356
# 70.950967483365
# 82.96491999904366
# 152.8820569844148
# 69.52476176685519
# 72.76852411089132
# 71.37892007877485
# 70.52096960936952
# 77.02098990754398
# 75.55430288602962
# 76.47785628455615
# 72.87099385557815
# 150.4960359440978
# 70.79607408952319
# 74.92140645927479
# 73.14044510485675
# 68.27876631599146
# 72.4296210533843
# 77.73550114431633
# 72.83116535554129
# 74.41748928417847
# 75.54837345886268
# 76.43528618301323
# 79.42121281066382
# 79.84239875072696
# 80.5129094185424
# 73.11859022780737
# 74.30473995647887
# 75.97635277442548
# 74.42451789707887
# 84.86585682762423
# 72.79612546319713
# 70.7263479561158
# 72.9374667000196
# 68.90920993557482
# 70.0431833344567
# 65.75387396097557
# 72.28241086115538
# 70.71462677159916
# 69.59720545185412
# 73.10573748185459
# 71.68242293464455
# 79.95366845763832
# 75.90305607742155
# 78.73488054189502
# 80.27130890666274
# 77.31567757785538
# 67.80552508008626
# 68.9347033836964
# 74.07937200556324
# 72.90415173710835
# 78.15616453173374
# 74.06714029938809
# 73.68213305732642
# 67.57296416906134
# 68.193317123636
# 68.38674201812765
# 74.09428903968004
# 66.67111904536743
# 69.71533557844313
# 65.8059667439011
# 70.45003581072628
# 61.81082893980236
# 61.5119091558858
# 70.85923838496156
# 73.02700945244521
# 65.85719310254638
# 67.53977540261744
# 58.04961516364535
# 68.91855860646952
# 69.898282881731
# 70.33158410936935
# 62.69007200797964
# 63.20111357058475
# 64.64934325679988
# 65.21014134908089
# 69.90666126013429
# 72.26869880450937
# 75.1420114182551
# 77.44223686236138
# 77.86005797282519
# 78.05976728541904
# 70.11638557321736
# 80.10726042547738
# 78.50164936744837
# 78.279190390463
# 79.45461011535873
# 79.93520569832627
# 71.81912969782887
# 73.87691176843819
# 81.39031938366172
# 78.98707523859343
# 77.42186114025235
# 82.86218500033767
# 83.14130585786945
# 72.44999850489658
# 75.19815704686307
# 83.25140304334501
# 80.02445703705735
# 74.61367516877989
# 73.98815498443969
# 75.09577665129243
# 71.47571597950508
# 69.57767383838275
# 68.93196553101042
# 63.25727830796298
# 67.11835869546884
# 69.33633487571397
# 74.39338886449346
# 73.07803721655173
# 70.65527949776296
# 72.74742667447141
# 73.72236285457888
# 67.3625081553449
# 67.9208518831333
# 75.93424429487942
# 64.92113564845413
# 68.65071276582555
# 72.00183344375878
# 73.09012419173823
# 67.32092853217752
# 67.51342496263213
# 70.92548021769696
# 72.39154111292457
# 75.6776666294788
# 70.79624254977384
# 67.88041077782232
# 74.4197709571409
# 71.15832981224736
# 71.35623841273873
# 77.45207438859872
# 75.03792959483317
# 74.94432097726234
# 72.95193657389592
# 74.16829108308816
# 68.89815549739717
# 69.2092898868249
# 79.87113681369847
# 70.15785166305949
# 80.22871098216841
# 74.07781688697446
# 70.23171991144766
# 72.48060555286611
# 75.00458275439912
# 76.19809959241891
# 77.55717767857583
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-27de386e409a> in <module>
#      11     ret, im = cam.read()
#      12     gray=cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
# ---> 13     faces=faceCascade.detectMultiScale(gray, 1.2,5)
#      14     for(x,y,w,h) in faces:
#      15         cv2.rectangle(im,(x,y),(x+w,y+h),(225,0,0),2)
#
# KeyboardInterrupt:
